# %%
# %matplotlib inline
import os
import re
from collections import defaultdict
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#result_dir = 'gnr_aws/deepseek-ai--DeepSeek-R1-Distill-Llama-8B'
result_dir = 'spr_aws'
#csv_file = 'gnr_aws/result_v1_spr_full_sys_sweep.csv'

# %%
group1 = ['Llama-3.2-1B', 'DeepSeek-R1-Distill-Qwen-1.5B', 'Llama-3.2-3B-Instruct']
group2 = ['Llama-2-7b-chat-hf', 'Llama-3.1-8B-Instruct', 'DeepSeek-R1-Distill-Llama-8B']
group3 = ['Llama-2-13b-chat-hf', 'DeepSeek-R1-Distill-Qwen-14B']

# %%
def get_json(fn):
    j = None
    try:
        with open(fn, 'r') as f:
            j = json.load(f)
    except Exception as e:
        print(f"Opening file {fn} failed with exception {e}")
        #sys.exit(1)
    return j

def get_result_files(directory):
    all_files = defaultdict(list)
    for root, dirs, files in os.walk(directory):
        for file in files:
            r = root[len(directory)+1:].split('/')
            c = file.split('-')[1]
            key = f"{r[0].split('--')[1]}+{r[1]}+{c}"
            all_files[key].append(os.path.join(root, file))            
    return all_files

def extract_results_from_json(fn):
    j = get_json(fn)
    return {
        'Model': j['model_id'],
        'Input Tokens': int(j['total_input_tokens']/j['num_prompts']),
        'Output Tokens': int(j['total_output_tokens']/j['num_prompts']),
        'Concurrency': int(j['request_rate']),
        'Output tput (tokens/sec)': round(j['output_throughput'], 2),
        'Total tput (tokens/sec)': round(j['total_token_throughput'], 2),
        'TTFT avg (ms)': round(j['mean_ttft_ms'], 2),
        'TTFT P50 (ms)': round(j['p50_ttft_ms'], 2),
        'TTFT P90 (ms)': round(j['p90_ttft_ms'], 2),
        'TTFT P99 (ms)': round(j['p99_ttft_ms'], 2),
        'TPOT avg (ms)': round(j['mean_tpot_ms'], 2),
        'TPOT P50 (ms)': round(j['p50_tpot_ms'], 2),
        'TPOT P90 (ms)': round(j['p90_tpot_ms'], 2),
        'TPOT P99 (ms)': round(j['p99_tpot_ms'], 2),
        'Request Throughput': round(j['request_throughput'], 2),
        'Request Latency avg (s)': round(j['mean_e2el_ms']/1000, 2),
        'Request Latency P50 (s)': round(j['p50_e2el_ms']/1000, 2),
        'Request Latency P90 (s)': round(j['p90_e2el_ms']/1000, 2),
        'Request Latency P99 (s)': round(j['p99_e2el_ms']/1000, 2),
    }

# %%
files = get_result_files(result_dir)

# %%
dfs = dict()
for k in files:
    values = []
    for f in files[k]:
        values.append(extract_results_from_json(f))
    dfs[k] = pd.DataFrame(values)
    dfs[k] = dfs[k].iloc[1:]

# %%
#model = 'DeepSeek-R1-Distill-Qwen-14B'
model = 'DeepSeek-R1-Distill-Qwen-1.5B'
#model = 'Llama-3.2-1B'

#IO = 'I100-O300+C2'
IO = 'I1000-O1000+C2'
#IO = 'I10000-O1500+C2'
#IO = 'I1000-O1000+C20'

dfs[model+'+'+IO]
# Out:
#                                        Model  Input Tokens  Output Tokens  \
# 1  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 2  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 3  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 4  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 5  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 6  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 7  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 8  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
# 9  deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B          1000           1000
#
#    Concurrency  Output tput (tokens/sec)  Total tput (tokens/sec)  \
# 1            2                     73.38                   146.76
# 2            2                     73.19                   146.38
# 3            2                     72.82                   145.63
# 4            2                     73.22                   146.45
# 5            2                     73.39                   146.78
# 6            2                     73.25                   146.50
# 7            2                     73.18                   146.36
# 8            2                     73.43                   146.87
# 9            2                     73.52                   147.03
#
#    TTFT avg (ms)  TTFT P50 (ms)  TTFT P90 (ms)  TTFT P99 (ms)  TPOT avg (ms)  \
# 1          48.66          48.66          56.81          58.64          26.76
# 2          47.36          47.36          54.46          56.06          26.84
# 3          47.42          47.42          54.20          55.73          26.98
# 4          47.17          47.17          53.93          55.45          26.82
# 5          49.15          49.15          57.47          59.35          26.76
# 6          47.61          47.61          54.26          55.75          26.81
# 7          47.86          47.86          55.22          56.87          26.84
# 8          47.67          47.67          55.17          56.85          26.75
# 9          48.66          48.66          56.77          58.59          26.71
#
#    TPOT P50 (ms)  TPOT P90 (ms)  TPOT P99 (ms)  Request Throughput  \
# 1          26.76          26.77          26.77                0.07
# 2          26.84          26.84          26.84                0.07
# 3          26.98          26.98          26.98                0.07
# 4          26.82          26.83          26.83                0.07
# 5          26.76          26.76          26.76                0.07
# 6          26.81          26.81          26.81                0.07
# 7          26.84          26.84          26.84                0.07
# 8          26.75          26.75          26.75                0.07
# 9          26.71          26.72          26.72                0.07
#
#    Request Latency avg (s)  Request Latency P50 (s)  Request Latency P90 (s)  \
# 1                    26.79                    26.79                    26.79
# 2                    26.86                    26.86                    26.86
# 3                    27.00                    27.00                    27.00
# 4                    26.84                    26.84                    26.85
# 5                    26.78                    26.78                    26.79
# 6                    26.83                    26.83                    26.84
# 7                    26.86                    26.86                    26.87
# 8                    26.77                    26.77                    26.77
# 9                    26.74                    26.74                    26.74
#
#    Request Latency P99 (s)
# 1                    26.79
# 2                    26.86
# 3                    27.00
# 4                    26.85
# 5                    26.79
# 6                    26.84
# 7                    26.87
# 8                    26.77
# 9                    26.74

# %%
def get_plot_df(models, io, col, c):
    d = defaultdict(list)
    for m in models:
        d[m] += (dfs[f"{m}+{io}+{c}"][col].tolist())
    df = pd.DataFrame(d)
    df.index = np.arange(1, len(df) + 1)
    return df


def create_box_plot(df, title, xlabel, ylabel):
    fig, ax = plt.subplots(figsize=(12, 6))
    df.boxplot()
    plt.tight_layout()
    plt.show()


def create_line_plot(df, title, xlabel, ylabel):
    fig, ax = plt.subplots(figsize=(12, 3))
    df.plot.line(
        ax=ax,
        style='o-',  # Circle markers 
        linewidth=2,
        markersize=8,
        #color=['navy', 'crimson'],
        title=title
    )
    ax.set_ylim(bottom=0, top=max(df.max())+20)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    # Remove all borders (spines)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, color='#EEEEEE', linestyle='--', linewidth=0.8, zorder=0)
    ax.xaxis.grid(True, color='#EEEEEE', linestyle='--', linewidth=0.8, zorder=0)
    
    # Place legend at the rightmost corner
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1))  # Moves legend outside plot area[8]
    
    plt.tight_layout()
    plt.show()


def create_grouped_bar_graph(data, group_labels, bar_labels, title, xlabel, ylabel):
    num_groups = len(data)
    num_bars = len(data[0])
    
    #fig, ax = plt.subplots(figsize=(10, 4))
    fig, ax = plt.subplots(figsize=(12, 3))
    
    index = np.arange(num_bars)
    #bar_width = 0.8 / num_groups
    bar_width = 0.4 / num_groups
    opacity = 0.8
    
    for i in range(num_groups):
        ax.bar(index + i * bar_width, data[i], bar_width,
               alpha=opacity, label=group_labels[i])
    
    ax.set_xlabel(xlabel, fontweight='bold', fontsize=12, labelpad=10)
    ax.set_ylabel(ylabel, fontweight='bold', fontsize=12, labelpad=10)
    ax.set_title(title, fontweight='bold', fontsize=16, pad=20)
    ax.set_xticks(index + bar_width * (num_groups - 1) / 2)
    #ax.set_xticklabels(bar_labels, rotation=25, ha='right')
    ax.set_xticklabels(bar_labels, rotation=0, ha='center')
    
    ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
    
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, color='#EEEEEE', linestyle='--', linewidth=0.8, zorder=0)
    ax.xaxis.grid(False)
    
    for i, group in enumerate(data):
        for j, value in enumerate(group):
            if value != 0:
                #ax.text(j + i * bar_width, value, f'{value}', ha='center', va='bottom', fontweight='bold', fontsize=10)
                ax.text(j + i * bar_width, value, f'{value}', ha='center', va='bottom', fontsize=7)
            else:
                ax.text(j + i * bar_width, value, '', ha='center', va='bottom', fontsize=7)
    
    plt.tight_layout()
    plt.show()


def op_grouped_bars(models, col, c, ti, xl, yl):
    group_labels_c2 = ['100 input tokens', '1k input tokens', '10k input tokens']
    group_labels_c20 = ['1k input tokens']
    bar_labels = models
    title = ti
    xlabel = xl
    ylabel = yl
    
    if c == 'C2' or c == 'C1':
        data = [[] for _ in range(3)]
        for m in models:
            data[0].append(dfs[f"{m}+I100-O300+{c}"][col].median())
            data[1].append(dfs[f"{m}+I1000-O1000+{c}"][col].median())
            if f"{m}+I10000-O1500+C2" in dfs:
                data[2].append(dfs[f"{m}+I10000-O1500+{c}"][col].median())
            else:
                data[2].append(0)
        create_grouped_bar_graph(data, group_labels_c2, bar_labels, title, xlabel, ylabel)
    else:
        data = [[] for _ in range(1)]
        for m in models:
            data[0].append(dfs[f"{m}+I1000-O1000+{c}"][col].median())
        create_grouped_bar_graph(data, group_labels_c20, bar_labels, title, xlabel, ylabel)

# %% [markdown]
# # C2 C20

# %% [markdown]
# ## Output speed by input token count

# %%
op_grouped_bars(group1, 'Output tput (tokens/sec)', 'C2', 'Output Speed by Input Token Count, Concurrent reqs: 2', '', 'tokens/sec')

# %%
op_grouped_bars(group2, 'Output tput (tokens/sec)', 'C2', 'Output Speed by Input Token Count, Concurrent reqs: 2', '', 'tokens/sec')

# %%
op_grouped_bars(group1, 'Output tput (tokens/sec)', 'C20', 'Output Speed by Input Token Count, Concurrent reqs: 20', '', 'tokens/sec')

# %%
op_grouped_bars(group2, 'Output tput (tokens/sec)', 'C20', 'Output Speed by Input Token Count, Concurrent reqs: 20', '', 'tokens/sec')

# %%
df = get_plot_df(group1, 'I1000-O1000', 'Output tput (tokens/sec)', 'C2')
#create_box_plot(df, 'Output Speed Variance', '', 'tokens/sec')
create_line_plot(df, 'Output Speed, Over Time, Concurrent reqs: 2', 'Iteration', 'tokens/sec')

# %%
df = get_plot_df(group2, 'I1000-O1000', 'Output tput (tokens/sec)', 'C2')
create_line_plot(df, 'Output Speed, Over Time, Concurrent reqs: 2', 'Iteration', 'tokens/sec')

# %%
df = get_plot_df(group1, 'I1000-O1000', 'Output tput (tokens/sec)', 'C20')
create_line_plot(df, 'Output Speed, Over Time, Concurrent reqs: 20', 'Iteration', 'tokens/sec')

# %%
df = get_plot_df(group2, 'I1000-O1000', 'Output tput (tokens/sec)', 'C20')
create_line_plot(df, 'Output Speed, Over Time, Concurrent reqs: 20', 'Iteration', 'tokens/sec')

# %% [markdown]
# ## Time to First Token by Input Token Count

# %%
op_grouped_bars(group1, 'TTFT P50 (ms)', 'C2', 'Time to First Token by Input Token Count, Concurrent reqs: 2', '', 'milliseconds')

# %%
op_grouped_bars(group2, 'TTFT P50 (ms)', 'C2', 'Time to First Token by Input Token Count, Concurrent reqs: 2', '', 'milliseconds')

# %%
op_grouped_bars(group1, 'TTFT P50 (ms)', 'C20', 'Time to First Token by Input Token Count, Concurrent reqs: 20', '', 'milliseconds')

# %%
op_grouped_bars(group2, 'TTFT P50 (ms)', 'C20', 'Time to First Token by Input Token Count, Concurrent reqs: 20', '', 'milliseconds')

# %%
df = get_plot_df(group1, 'I1000-O1000', 'TTFT P50 (ms)', 'C2')
create_line_plot(df, 'Time to First Token, Over Time, Concurrent reqs: 2', 'Iteration', 'milliseconds')

# %%
df = get_plot_df(group2, 'I1000-O1000', 'TTFT P50 (ms)', 'C2')
create_line_plot(df, 'Time to First Token, Over Time, Concurrent reqs: 2', 'Iteration', 'milliseconds')

# %%
df = get_plot_df(group1, 'I1000-O1000', 'TTFT P50 (ms)', 'C20')
create_line_plot(df, 'Time to First Token, Over Time, Concurrent reqs: 20', 'Iteration', 'milliseconds')

# %%
df = get_plot_df(group2, 'I1000-O1000', 'TTFT P50 (ms)', 'C20')
create_line_plot(df, 'Time to First Token, Over Time, Concurrent reqs: 20', 'Iteration', 'milliseconds')

# %% [markdown]
# ## End-to-End Response Time by Input Token Count

# %%
op_grouped_bars(group1, 'Request Latency P50 (s)', 'C2', 'End-to-End Response Time by Input Token Count, Concurrent reqs: 2', '', 'seconds')

# %%
op_grouped_bars(group2, 'Request Latency P50 (s)', 'C2', 'End-to-End Response Time by Input Token Count, Concurrent reqs: 2', '', 'seconds')

# %%
op_grouped_bars(group1, 'Request Latency P50 (s)', 'C20', 'End-to-End Response Time by Input Token Count, Concurrent reqs: 20', '', 'seconds')

# %%
op_grouped_bars(group2, 'Request Latency P50 (s)', 'C20', 'End-to-End Response Time by Input Token Count, Concurrent reqs: 20', '', 'seconds')

# %%
df = get_plot_df(group1, 'I1000-O1000', 'Request Latency P50 (s)', 'C2')
create_line_plot(df, 'End-to-End Response Time, Over Time, Concurrent reqs: 2', 'Iteration', 'seconds')

# %%
df = get_plot_df(group2, 'I1000-O1000', 'Request Latency P50 (s)', 'C2')
create_line_plot(df, 'End-to-End Response Time, Over Time, Concurrent reqs: 2', 'Iteration', 'seconds')

# %%
df = get_plot_df(group1, 'I1000-O1000', 'Request Latency P50 (s)', 'C20')
create_line_plot(df, 'End-to-End Response Time, Over Time, Concurrent reqs: 20', 'Iteration', 'seconds')

# %%
df = get_plot_df(group2, 'I1000-O1000', 'Request Latency P50 (s)', 'C20')
create_line_plot(df, 'End-to-End Response Time, Over Time, Concurrent reqs: 20', 'Iteration', 'seconds')
